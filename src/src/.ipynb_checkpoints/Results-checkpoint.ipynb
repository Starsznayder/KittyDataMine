# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import re
from sklearn.metrics import balanced_accuracy_score, accuracy_score

# %%
def load_dataset(path):
    return pd.read_csv(path, sep=' ', header=None)

def remove_backspace(string):
    result = ''
    for char in string:
        if char == '\b':
            result = result[:-1]
        else:
            result += char
    return result

def load_json(path='iris_result.json'):
    with open(path, 'r') as f:
        string = f.read()
        string = remove_backspace(string)
        data = json.loads(string)
    return data

# %%
def plot_pca(X, c):
    # X = (X - X.mean(0))/X.std(0)
    _, vec = np.linalg.eigh(X.T @ X )
    Z = X @ vec
    plt.scatter(Z[:, -1], Z[:, -2], c=c)
    plt.title('True Values')
    plt.xlabel('PC0')
    plt.ylabel('PC1')
    plt.gca().set_aspect('equal')

# %%
def plot_distance(arr, c):
    # arr = np.zeros((X.shape[0], X.shape[0]))
    # for i in range(X.shape[0]):
    #     for j in range(X.shape[0]):
    #         arr[i, j] = metric(X[i], X[j])
    _, Z = np.linalg.eigh(arr)
    # Z = arr @ vec
    plt.scatter(Z[:, -1], Z[:, -2], c=c)
    plt.title('True Values')
    plt.xlabel('PC0')
    plt.ylabel('PC1')
    # plt.gca().set_aspect('equal')

# %%
def print_table(results):
    print("\\toprule")
    print(" measure & k-NN & k+NN & RIA & RIONA \\\\")
    print("\\midrule")
    print("accuracy ", end='')
    for k, v in results['measures']['accuracy'].items():
        print(f"& {v: .3f} ", end="")
    print("\\\\")
    print("balanced accuracy ", end='')
    for k, v in results['measures']['balanced_accuracy'].items():
        print(f"& {v: .3f} ", end="")
    print("\\\\")
    print("\\bottomrule")

# %%
results = load_json()

# %%
df = load_dataset('data/csv/iris.csv')

# %%
y = df[0].to_numpy()
X = df[[1,2,3,4]].to_numpy()

# %%
plot_pca(X, results['predictions']['target'])

# %%
plot_pca(X, results['predictions']['kmnn'])

# %%
plot_pca(X, results['predictions']['kpnn'])

# %%
plot_pca(X, results['predictions']['ria'])

# %%
plot_pca(X, results['predictions']['riona'])

# %%
results.keys()
# Out:
# dict_keys(['file_name', 'number_of_observations', 'number_of_attributes', 'k', 'metadata', 'measures', 'predictions'])

# %%
print_table(results)
# Out:
# \toprule
#  measure & k-NN & k+NN & RIA & RIONA \\
# \midrule
# accuracy &  0.953 &  0.953 &  0.880 &  0.953 \\
# balanced accuracy &  0.953 &  0.953 &  0.880 &  0.953 \\
# \bottomrule

# %%
np.mean([d['decisive'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 0.03355704697986577

# %%
np.mean([d['distance'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 6.094756919463086

# %%
plot_pca(X, [True] + [d['decisive'] for d in results['metadata'][0]['kmnn']['metadata']])

# %%
plot_pca(X, [True] + [d['decisive'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_pca(X, [True] + [d['decisive'] for d in results['metadata'][0]['ria']['metadata']]) # All True

# %%
plot_pca(X, [True] + [d['decisive'] for d in sorted(results['metadata'][0]['riona']['metadata'], key=lambda x: x['ngbr_id'])])

# %%
plot_pca(X, [0] + [d['distance'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_pca(X, [True] + [d['consistent'] for d in results['metadata'][0]['ria']['metadata']]) # All True

# %%
results = load_json('tae_result.json')

# %%
results.keys()
# Out:
# dict_keys(['file_name', 'number_of_observations', 'number_of_attributes', 'k', 'metadata', 'measures', 'predictions'])

# %%
df = load_dataset('data/csv/tae.csv')

# %%
y = df[0].to_numpy()
X = df[[1,2,3,4,5]].to_numpy()

# %%
from imblearn.metrics.pairwise import ValueDifferenceMetric

# %%
(X[:, [1,2,4]] @ X[:, [1,2,4]].T).max()
# Out:
# 9.874875188702523

# %%
(X[:, [1,2,4]] @ X[:, [1,2,4]].T).min()
# Out:
# -6.477886528515157

# %%
D = (
    2 * np.exp(-ValueDifferenceMetric().fit(X[:, 0:1], y).pairwise(X[:, 0:1])) - 1 + 
    2 * np.exp(-ValueDifferenceMetric().fit(X[:, 3:4], y).pairwise(X[:, 3:4])) - 1 +
    X[:, [1,2,4]] @ X[:, [1,2,4]].T
    # np.abs(X[:, 1:2] - X[:, 1:2].T) +
    # np.abs(X[:, 2:3] - X[:, 2:3].T) +
    # np.abs(X[:, 4:5] - X[:, 4:5].T)
)

# %%
def plot_sim(arr, c, title="target"):
    _, Z = np.linalg.eigh(arr)
    plt.scatter(Z[:, -1], Z[:, -2], c=c)
    plt.title(title)
    plt.xlabel('PC0')
    plt.ylabel('PC1')
    # plt.gca().set_aspect('equal')

# %%
plot_sim(D, results['predictions']['target'], 'target')

# %%
plot_sim(D, results['predictions']['kmnn'], 'kmnn')

# %%
plot_sim(D, results['predictions']['kpnn'], 'kpnn')

# %%
plot_sim(D, results['predictions']['ria'], 'ria')

# %%
plot_sim(D, results['predictions']['riona'])

# %%
print_table(results)
# Out:
# \toprule
#  measure & k-NN & k+NN & RIA & RIONA \\
# \midrule
# accuracy &  0.517 &  0.523 &  0.656 &  0.656 \\
# balanced accuracy &  0.517 &  0.523 &  0.657 &  0.657 \\
# \bottomrule

# %%
np.mean([d['decisive'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 0.03333333333333333

# %%
np.mean([d['distance'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 3.4610934399999995

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['kmnn']['metadata']])

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['ria']['metadata']]) # All True

# %%
plot_sim(D, [True] + [d['decisive'] for d in sorted(results['metadata'][0]['riona']['metadata'], key=lambda x: x['ngbr_id'])])

# %%
plot_sim(D, [0] + [d['distance'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_sim(D, [True] + [d['consistent'] for d in results['metadata'][0]['ria']['metadata']]) # All True

# %%
results = load_json('zoo_result.json')

# %%
results.keys()
# Out:
# dict_keys(['file_name', 'number_of_observations', 'number_of_attributes', 'k', 'metadata', 'measures', 'predictions'])

# %%
df = load_dataset('data/csv/zoo.csv')

# %%
y = df[0].to_numpy()
X = df.iloc[:, 1:].to_numpy()

# %%
from imblearn.metrics.pairwise import ValueDifferenceMetric

# %%
D = 0
for i in range(16):
    D += 2 * np.exp(-ValueDifferenceMetric().fit(X[:, i:i+1], y).pairwise(X[:, i:i+1])) - 1

# %%
def plot_sim(arr, c, title="target"):
    _, Z = np.linalg.eigh(arr)
    plt.scatter(Z[:, -1], Z[:, -2], c=c)
    plt.title(title)
    plt.xlabel('PC0')
    plt.ylabel('PC1')
    # plt.gca().set_aspect('equal')

# %%
plot_sim(D, results['predictions']['target'], 'target')

# %%
plot_sim(D, results['predictions']['kmnn'], 'kmnn')

# %%
plot_sim(D, results['predictions']['kpnn'], 'kpnn')

# %%
plot_sim(D, results['predictions']['ria'], 'ria')

# %%
plot_sim(D, results['predictions']['riona'])

# %%
print_table(results)
# Out:
# \toprule
#  measure & k-NN & k+NN & RIA & RIONA \\
# \midrule
# accuracy &  0.941 &  0.931 &  0.851 &  0.950 \\
# balanced accuracy &  0.871 &  0.843 &  0.654 &  0.871 \\
# \bottomrule

# %%
np.mean([d['decisive'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 0.05

# %%
np.mean([d['distance'] for d in results['metadata'][1]['kmnn']['metadata']])
# Out:
# 10.374447320000002

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['kmnn']['metadata']])

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_sim(D, [True] + [d['decisive'] for d in results['metadata'][0]['ria']['metadata']]) # All True

# %%
plot_sim(D, [True] + [d['decisive'] for d in sorted(results['metadata'][0]['riona']['metadata'], key=lambda x: x['ngbr_id'])])

# %%
plot_sim(D, [0] + [d['distance'] for d in results['metadata'][0]['kpnn']['metadata']])

# %%
plot_sim(D, [True] + [d['consistent'] for d in results['metadata'][0]['ria']['metadata']]) # All True
