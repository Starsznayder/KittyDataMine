# %%
import json

# %%
with open('iris_result.json', 'r') as f:
    string = f.read()
    data = json.loads(string)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
#       1 with open('iris_result.json', 'r') as f:
#       2     string = f.read()
# ----> 3     data = json.loads(string)
#
# File ~/ProgramFiles/miniconda3/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File ~/ProgramFiles/miniconda3/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
string[50278:53498]
# Out:
# 'd": 112, "decision": 2, "distance": 7.699999, "consistent": null, "decisive": false}, {"ngbr_id": 113, "decision": 1, "distance": 4.100000, "consistent": null, "decisive": false}, {"ngbr_id": 114, "decision": 0, "distance": 1.400000, "consistent": null, "decisive": false}, {"ngbr_id": 115, "decision": 2, "distance": 6.799999, "consistent": null, "decisive": false}, {"ngbr_id": 116, "decision": 1, "distance": 4.000000, "consistent": null, "decisive": false}, {"ngbr_id": 117, "decision": 1, "distance": 6.099999, "consistent": null, "decisive": false}, {"ngbr_id": 118, "decision": 2, "distance": 9.099999, "consistent": null, "decisive": false}, {"ngbr_id": 119, "decision": 1, "distance": 4.599999, "consistent": null, "decisive": false}, {"ngbr_id": 121, "decision": 0, "distance": 1.100000, "consistent": null, "decisive": false}, {"ngbr_id": 122, "decision": 0, "distance": 1.400000, "consistent": null, "decisive": false}, {"ngbr_id": 123, "decision": 0, "distance": 1.300000, "consistent
# ...

# %%
string.split('\n')[8]
# Out:
# '"ria": {"target": 0, metadata: {"ngbr_id": 1, "decision": 0, "distance": null, "consistent": true, "decisive": true}, {"ngbr_id": 2, "decision": 0, "distance": null, "consistent": true, "decisive": true}, {"ngbr_id": 3, "decision": 2, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 4, "decision": 0, "distance": null, "consistent": true, "decisive": true}, {"ngbr_id": 5, "decision": 1, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 6, "decision": 1, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 7, "decision": 1, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 8, "decision": 0, "distance": null, "consistent": true, "decisive": true}, {"ngbr_id": 9, "decision": 2, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 10, "decision": 2, "distance": null, "consistent": false, "decisive": true}, {"ngbr_id": 11, "decision": 2, "distance": null, "consistent": false, "decisive": true}, 
# ...

# %%
strings = string.split('\n')

# %%
strings[6]
# Out:
# '{"kmnn": {"target": 0,  "prediction": 0, "metadata": [{"ngbr_id": 1, "decision": 0, "distance": 2.100000, "consistent": null, "decisive": false}, {"ngbr_id": 2, "decision": 0, "distance": 0.800000, "consistent": null, "decisive": false}, {"ngbr_id": 3, "decision": 2, "distance": 7.900000, "consistent": null, "decisive": false}, {"ngbr_id": 4, "decision": 0, "distance": 0.700000, "consistent": null, "decisive": false}, {"ngbr_id": 5, "decision": 1, "distance": 5.400000, "consistent": null, "decisive": false}, {"ngbr_id": 6, "decision": 1, "distance": 5.200000, "consistent": null, "decisive": false}, {"ngbr_id": 7, "decision": 1, "distance": 4.099999, "consistent": null, "decisive": false}, {"ngbr_id": 8, "decision": 0, "distance": 1.900000, "consistent": null, "decisive": false}, {"ngbr_id": 9, "decision": 2, "distance": 9.099999, "consistent": null, "decisive": false}, {"ngbr_id": 10, "decision": 2, "distance": 8.099999, "consistent": null, "decisive": false}, {"ngbr_id": 11, "decis
# ...
